# %% [markdown]
# # Use this notebook for your 3 choices of APIs

# %%
import pandas as pd
import requests 
from pandas import json_normalize

# %% [markdown]
# #### Nager.date (https://date.nager.at/swagger/index.html)

# %% [markdown]
# We use json_normalize and we can obtain a dataframe with a list of the public holidays worldwide for the next 7 days.

# %%
response = requests.get('https://date.nager.at/api/v3/NextPublicHolidaysWorldwide')
print("dates", response.status_code)
# Out:
# dates 200

# %%
# response.content

# %%
import json
dates = response.json()

# %%
# dates

# %%
flattened_dates = json_normalize(dates)

# %%
flattened_dates
# Out:
#           date                                          localName  \
# 0   2023-09-06                                Ден на съединението
# 1   2023-09-07                               Dia da Independência
# 2   2023-09-07                                     Jeûne genevois
# 3   2023-09-07                                    Dia da Victória
# 4   2023-09-08                           Mare de Déu de Meritxell
# 5   2023-09-08                                    Día de Asturias
# 6   2023-09-08                                 Día de Extremadura
# 7   2023-09-08                                       Maria Geburt
# 8   2023-09-08           Ден на независноста, Den na nezavisnosta
# 9   2023-09-08                                        Il-Vittorja
# 10  2023-09-08                 Festa della natività della madonna
# 11  2023-09-08  Día del Virgen del Valle, aparicion del Virgen...
# 12  2023-09-10                            Saint George's Caye Day
# 13  2023-09-10                             Gibraltar National Day
# 14  2023-09-11                        Diada Nacional de Catalunya
#
#                                                  name countryCode  fixed  \
# 0                                     Unification Day          BG   True
# 1                                    Independence Day          BR   True
# 2                                      Geneva Prayday          CH  False
# 3                                         Victory Day          MZ   True
# 4                                    National Holiday          AD   True
# 5                                     Day of Asturias          ES   True
# 6                                  Day of Extremadura          ES   True
# 7                                Nativity of Our Lady          LI   True
# 8                                    Independence Day          MK   True
# 9                      Feast of Our Lady of Victories          MT   True
# 10                                   Nativity of Mary          VA   True
# 11  Birth of the Blessed Virgin Mary and feasts of...          VE   True
# 12                            Saint George's Caye Day          BZ  False
# 13                             Gibraltar National Day          GI   True
# 14                          National Day of Catalonia          ES   True
#
#     global counties launchYear     types
# 0     True     None       None  [Public]
# 1     True     None       None  [Public]
# 2    False  [CH-GE]       None  [Public]
# 3     True     None       None  [Public]
# 4     True     None       None  [Public]
# 5    False  [ES-AS]       None  [Public]
# 6    False  [ES-EX]       None  [Public]
# 7     True     None       None  [Public]
# 8     True     None       None  [Public]
# 9     True     None       None  [Public]
# 10    True     None       None  [Public]
# 11    True     None       None  [Public]
# 12    True     None       None  [Public]
# 13    True     None       None  [Public]
# 14   False  [ES-CT]       None  [Public]

# %% [markdown]
# #### eBird (https://documenter.getpostman.com/view/664302/S1ENwy59#auth-info-124a9625-7cc9-48d5-be64-bb4fa0d59f46).

# %% [markdown]
# For a list of birth observations.

# %% [markdown]
# First, we needed to create an account and obtain an API token.

# %%
api_token = input('Enter ebird api token: ')

# %%
url = 'https://api.ebird.org/v2/data/obs/KZ/recent'
headers = {
    'X-eBirdApiToken': api_token}

# Realiza la solicitud GET con el encabezado personalizado
response = requests.get(url, headers=headers)

# %%
# response.content

# %%
import json
observs = response.json()

# %%
# observs

# %%
observs_flatt = json_normalize(observs)

# %% [markdown]
# We use json_normalize and obtain a list of observations. We have the name and number of species seen, the location with latitude and longitude, etc.

# %%
observs_flatt
# Out:
#     speciesCode                comName                sciName      locId  \
# 0        rocpig            Rock Pigeon          Columba livia   L3089582
# 1        eutspa  Eurasian Tree Sparrow        Passer montanus   L3089582
# 2       graher1             Gray Heron          Ardea cinerea   L3089582
# 3        barswa           Barn Swallow        Hirundo rustica   L3089582
# 4        houspa          House Sparrow      Passer domesticus   L3089582
# ..          ...                    ...                    ...        ...
# 180     azutit2              Azure Tit       Cyanistes cyanus  L26735745
# 181     rutshr2      Red-tailed Shrike  Lanius phoenicuroides  L10200253
# 182     rinphe1   Ring-necked Pheasant    Phasianus colchicus  L10200253
# 183     brodip1           Brown Dipper       Cinclus pallasii   L9998085
# 184      rudshe         Ruddy Shelduck     Tadorna ferruginea   L1577085
#
#                                         locName             obsDt  howMany  \
# 0                            Atyrau--Ural River  2023-09-05 06:51      3.0
# 1                            Atyrau--Ural River  2023-09-05 06:51      2.0
# 2                            Atyrau--Ural River  2023-09-05 06:51      2.0
# 3                            Atyrau--Ural River  2023-09-05 06:51      7.0
# 4                            Atyrau--Ural River  2023-09-05 06:51      4.0
# ..                                          ...               ...      ...
# 180                               Bachi village  2023-08-24 06:00      2.0
# 181                 Altyn Emel NP--General Area  2023-08-23 17:00      NaN
# 182                 Altyn Emel NP--General Area  2023-08-23 17:00      4.0
# 183                                 Alma-Arasan  2023-08-22 14:00      1.0
# 184  Ile Alatau NP--Big Almaty Lake (IBA KZ098)  2023-08-22 12:45      1.0
#
#            lat        lng  obsValid  obsReviewed  locationPrivate       subId  \
# 0    47.105536  51.918898      True        False            False  S149032459
# 1    47.105536  51.918898      True        False            False  S149032459
# 2    47.105536  51.918898      True        False            False  S149032459
# 3    47.105536  51.918898      True        False            False  S149032459
# 4    47.105536  51.918898      True        False            False  S149032459
# ..         ...        ...       ...          ...              ...         ...
# 180  44.159040  78.746261      True        False             True  S147962151
# 181  44.002062  78.838169      True        False            False  S147921256
# 182  44.002062  78.838169      True        False            False  S147921256
# 183  43.084900  76.905750      True        False            False  S147856717
# 184  43.052565  76.985021      True        False            False  S147852441
#
#     exoticCategory
# 0                N
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 180            NaN
# 181            NaN
# 182            NaN
# 183            NaN
# 184            NaN
#
# [185 rows x 14 columns]

# %% [markdown]
# #### Art Institute of Chicago (https://api.artic.edu/docs/#introduction)

# %% [markdown]
# For a list of art pieces in the Art Institute of Chicago.

# %%
response = requests.get('https://api.artic.edu/api/v1/artworks')
print("chicago", response.status_code)
# Out:
# chicago 200

# %%
# response.content

# %%
import json
pieces = response.json()

# %% [markdown]
# We get 12 pieces of art per page. We have the link for the next page, so we could be iterating for retreiving all the info.

# %%
# pieces

# %% [markdown]
# In this case, we need to use json_normalize on the key 'data'. That's where we find the info of each piece of art.

# %%
pieces_flatt = json_normalize(pieces['data'])

# %% [markdown]
# We get a lot of information for each piece. Title, artist, dates, size, descriptions, etc.

# %%
pieces_flatt['artist_title']
# Out:
# 0       Atelier Martine
# 1       Atelier Martine
# 2       Atelier Martine
# 3       Atelier Martine
# 4       Atelier Martine
# 5         Gaylen Gerber
# 6         Gaylen Gerber
# 7       Atelier Martine
# 8       Atelier Martine
# 9       Atelier Martine
# 10    Giovanni di Paolo
# 11    Giovanni di Paolo
# Name: artist_title, dtype: object

# %%
pieces_flatt
# Out:
#         id api_model                                      api_link  \
# 0    86376  artworks   https://api.artic.edu/api/v1/artworks/86376
# 1    86405  artworks   https://api.artic.edu/api/v1/artworks/86405
# 2    86403  artworks   https://api.artic.edu/api/v1/artworks/86403
# 3   190554  artworks  https://api.artic.edu/api/v1/artworks/190554
# 4    33141  artworks   https://api.artic.edu/api/v1/artworks/33141
# 5   204273  artworks  https://api.artic.edu/api/v1/artworks/204273
# 6   204272  artworks  https://api.artic.edu/api/v1/artworks/204272
# 7    86364  artworks   https://api.artic.edu/api/v1/artworks/86364
# 8    86368  artworks   https://api.artic.edu/api/v1/artworks/86368
# 9    86367  artworks   https://api.artic.edu/api/v1/artworks/86367
# 10   16159  artworks   https://api.artic.edu/api/v1/artworks/16159
# 11   16156  artworks   https://api.artic.edu/api/v1/artworks/16156
#
#     is_boosted                                           title alt_titles  \
# 0        False              Panel (Dress or Furnishing Fabric)       None
# 1        False              Panel (Dress or Furnishing Fabric)       None
# 2        False                                           Panel       None
# 3        False                                         Begonia       None
# 4        False                                        Fragment       None
# 5        False                                        Untitled       None
# 6        False                                        Untitled       None
# 7        False              Panel (Dress or Furnishing Fabric)       None
# 8        False              Panel (Dress or Furnishing Fabric)       None
# 9        False              Panel (Dress or Furnishing Fabric)       None
# 10       False                                  Ecce Agnus Dei       None
# 11       False  Saint John the Baptist Entering the Wilderness       None
#
#    main_reference_number  has_not_been_viewed_much boost_rank  date_start  \
# 0               1924.205                      True       None      1915.0
# 1               1924.455                      True       None      1913.0
# 2               1924.453                      True       None      1920.0
# 3               2007.352                      True       None      1915.0
# 4                1970.60                     False       None      1920.0
# 5            Obj: 204273                      True       None         NaN
# 6            Obj: 204272                      True       None         NaN
# 7               1924.198                     False       None      1920.0
# 8               1924.201                      True       None      1915.0
# 9               1924.200                      True       None      1920.0
# 10             1933.1011                     False       None      1455.0
# 11             1933.1010                     False       None      1455.0
#
#     ...                                     thumbnail.lqip thumbnail.width  \
# 0   ...  ......            1515
# 1   ...  ......            2261
# 2   ...  ......            1572
# 3   ...  ......            3398
# 4   ...  ......            1984
# 5   ...  ......            2385
# 6   ...  ......            2746
# 7   ...  ......            2166
# 8   ...  ......            2106
# 9   ...  ......            2149
# 10  ...  ......            4909
# 11  ...  ......            2684
#
#    thumbnail.height                                 thumbnail.alt_text  \
# 0              2250   A work made of silk, satin weave; block printed.
# 1              2250  A work made of cotton and linen, plain weave; ...
# 2              1069  A work made of cotton and linen, plain weave; ...
# 3              6311  A work made of linen, plain weave; block printed.
# 4              2250  A work made of linen, plain weave; block printed.
# 5              2338                      A work made of oil on canvas.
# 6              2729                      A work made of oil on canvas.
# 7              2250  A work made of cotton and linen; plain weave; ...
# 8              2250  A work made of cotton and linen, plain weave; ...
# 9              2250  A work made of cotton and linen, plain weave; ...
# 10             9108                   A work made of tempera on panel.
# 11             5294                   A work made of tempera on panel.
#
#    color.h color.l color.s color.percentage color.population color
# 0    214.0    42.0    36.0         0.000568              6.0   NaN
# 1     38.0    59.0    83.0         0.002686             19.0   NaN
# 2    209.0    61.0    62.0         0.432470           2089.0   NaN
# 3    318.0    30.0    96.0         0.049162            649.0   NaN
# 4     48.0    30.0    30.0         0.047772            385.0   NaN
# 5      NaN     NaN     NaN              NaN              NaN   NaN
# 6      NaN     NaN     NaN              NaN              NaN   NaN
# 7     46.0    52.0    24.0         0.073531            543.0   NaN
# 8     47.0    52.0    78.0         0.005135             39.0   NaN
# 9     38.0    49.0    66.0         0.002152             16.0   NaN
# 10    40.0    48.0    67.0         0.000531              7.0   NaN
# 11     8.0    51.0    49.0         0.001498             21.0   NaN
#
# [12 rows x 103 columns]
